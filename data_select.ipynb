# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import sklearn
import random
import os
import csv
from sklearn.ensemble import RandomForestClassifier

train_filepath = 'data/train.csv'
rd = pd.read_table(train_filepath)
traindata = pd.DataFrame(rd)

test_filepath = 'data/test.csv'
test_f = pd.read_table(test_filepath)
testdata = pd.DataFrame(test_f)

# %%
for i in range (len(traindata['Step Duration (sec)'])):
    if math.isnan(traindata['Step Duration (sec)'][i]):
        traindata['Step Duration (sec)'][i] = -1


for i in range (len(traindata['Corrects'])):
    if math.isnan(traindata['Corrects'][i]):
        traindata['Corrects'][i] = -1

for i in range (len(testdata['Step Duration (sec)'])):
    if math.isnan(testdata['Step Duration (sec)'][i]):
        testdata['Step Duration (sec)'][i] = -1


for i in range (len(testdata['Corrects'])):
    if math.isnan(testdata['Corrects'][i]):
        testdata['Corrects'][i] = -1
# Out:
# C:\Users\wyh_a\AppData\Local\Temp\ipykernel_18072\1587344069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindata['Step Duration (sec)'][i] = -1
# C:\Users\wyh_a\AppData\Local\Temp\ipykernel_18072\1587344069.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testdata['Step Duration (sec)'][i] = -1
# C:\Users\wyh_a\AppData\Local\Temp\ipykernel_18072\1587344069.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
csv_path = 'data/test_select.csv'
df_new = testdata
x = np.array(testdata['Correct First Attempt'])
for i in range(0, len(x)):
    if math.isnan(x[i]):
        df_new = df_new.drop([i],axis=0)
df_new_cpy = df_new['Correct First Attempt']
df_new_cpy.to_csv(csv_path)

# %%
X = traindata.loc[:,['Step Duration (sec)', 'Corrects']]
Y = traindata['Correct First Attempt']

model = RandomForestClassifier()
model.fit(X, Y)
# Out:
# RandomForestClassifier()

# %%
X_test = df_new.loc[:,['Step Duration (sec)', 'Corrects']]
pred = model.predict(X_test)
pre = pd.DataFrame(pred)
df_new
# Out:
#           Row Anon Student Id  \
# 14      21616      8o0mJnIpFH
# 15      22178      8o0mJnIpFH
# 16      22320      8o0mJnIpFH
# 17      22862      8o0mJnIpFH
# 18      23277      8o0mJnIpFH
# ...       ...             ...
# 1135  1075314      C0qLCIhI0O
# 1136  1076841      e95f4UtF4I
# 1137  1076862      e95f4UtF4I
# 1138  1076891      e95f4UtF4I
# 1139  1078861      JP20cryBg8
#
#                                       Problem Hierarchy    Problem Name  \
# 14                      Unit CTA1_06, Section CTA1_06-3           JAN05
# 15                          Unit ES_03, Section ES_03-6           EG51A
# 16                      Unit CTA1_08, Section CTA1_08-2           FEB03
# 17                         Unit ES_04, Section ES_04-15           LIT58
# 18                      Unit CTA1_10, Section CTA1_10-5     DISTFB08_SP
# ...                                                 ...             ...
# 1135                    Unit CTA1_24, Section CTA1_24-1          L5FB05
# ...

# %%
csv_path = 'data/result.csv'
df = pd.DataFrame(pred)
df_new = df_new.loc[:,['Step Duration (sec)', 'Corrects']]
df_new.to_csv(csv_path)
